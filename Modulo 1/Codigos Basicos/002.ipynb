# %% [markdown]
# ## função print ()
# # a funçao print () e uma das mais importantes e usada n linguagem python. sua funçao e basicamente exibir mensagens na tela ou envialas para outr dispositivos, como imprimir dentro de um arquivo de texto.
#
# #No python 3, print() e uma funçao interna, de modo que nao e nescessario importar nehuma biblioteca para poder utilizar

# %%
print ("meu primeiro print") #todo texto eve estar em aspas dupla ou simples
# Out:
# meu primeiro print

# %%
print ('meu segundo print') # quando uma palvra contem aspas as aspas inicias devem ser diferentes
# Out:
# meu segundo print

# %%
print(20 + 10) # o python realiza a operação que esta dentro de parenteses
# Out:
# 30

# %%
print ('20 + 15') # a operação entre aspas ira comprender que é um texto e nao uma operação paraser calculada
# Out:
# 20 + 15

# %%
print ('10+30',10+30)
# Out:
# 10+30 40

# %%
n = '1'
n2 = '3'
print (n+n2)  # neste exemplo o python faz a concatenação (unir) das 2 strhings
# Out:
# 13

# %%
nome = 'carlinhos'
sobrenome = 'dalva'
nome_completo = nome + ' '+ sobrenome
print (nome_completo)
# Out:
# carlinhos dalva
