# %%
nome = "carlinhos"
print (nome)
# Out:
# carlinhos

# %%
idade = 26
print (idade)
# Out:
# 26

# %%
# este é m exemple de numro inteir positivo
temperatura = 12 # variavel de armazenamento de numero negativo
print (temperatura) # print é uma função de saida
# Out:
# 12

# %% [markdown]
# variavel com numero decimal (float)

# %%
pi = 3.5344
print (pi)
# Out:
# 3.5344

# %%
 altura = (1.75) # em python os numeros decimais são escritos com "."

print (altura)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-283020145.py in <cell line: 0>()
# ----> 1 altura (1.75) # em python os numeros decimais são escritos com "."
#       2
#       3 print (altura)
#
# TypeError: 'float' object is not callable

# %% [markdown]
# variavel com valor booleano (bool)

# %%
estudante = True
print (estudante)
# Out:
# True

# %% [markdown]
# ## nomes de variaveis
#
# #pode
#
# *   começar co letra  ( n,numero, altura)
# *   pode conter numeros porem nao começar (n1, numero1 etc)
#
# # nao pode
#
#
# *   usar numero
# *   dar espaço EXEMPLO(nome_completo nome-completo nomecompleto)
#
#
#
#
# *   usar açentuçao ou caractere especiais (@ % $)
# *   Item da lista
#
#
#  #palavras reservadas

# %% [markdown]
# #errado
#  1idade =  12 # começar com nuero
#
#  meu nome = adolfo # espaço nao e permitido
#
# ## oque e snake_case
#  #snake_case e uma escrita usada para ome variavel, funçao e nomes em geral no codigo
#
#  ## poque usar snake_case
#  # deixa o codigo mais facil de ler# é o padrao reomendado pela comunidade python
#  # segue o PEF8, que o guia oficial do python
#
#  ## exemplos que nao usam snake_case

# %%
nomeCompleto = "maria" # usado em java
nomeCompleto = "maria" # pasalCase (usado em classes em python)
nomecompleto = "maria" # estilo dificil de ler

# %% [markdown]
# ##oque são variáveis

# %% [markdown]
# #tutorial variáveis

# %% [markdown]
# variável com texto (string)

# %% [markdown]
# variáveis são espaços da memória onde podemos guardar informações (como textos, números, resultados de cálculos etc) para usar depois.
