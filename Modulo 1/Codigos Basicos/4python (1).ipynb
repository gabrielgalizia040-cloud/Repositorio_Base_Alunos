# %% [markdown]
# # operadores relacionais

# %% [markdown]
# *   > maior
# *   >=maior igual
# *   < menor
# *   <= menor igual
# *   != diferente
# *   == igual

# %%
10 > 20 # 10 e maior que 20
# Out:
# False

# %%
10 < 20 # 10 e menor que 20
# Out:
# True

# %%
5+1 != 6 # 5+1 e diferente de 6
# Out:
# False

# %%
3+1 >= 4 # 3+1 e maior ou igual a 4
# Out:
# True

# %%
nome_aluno = "barbara"
nome_professora = "loren"

# %%
nome_aluno == nome_professora
# Out:
# False

# %% [markdown]
# # operadores logicos

# %% [markdown]
# *   AND(e)
# *   OR(ou)
#
# *   NOT(negaçao)

# %%
(10>20) and (20>30)
# Out:
# False

# %% [markdown]
# #and
#
# true + true = true
# true + false = false
# false + true = false
# false + false = false

# %%
(10>20) and (20>30) #false + false = false
# Out:
# False

# %%
(10<20) and (20<30)
# Out:
# True

# %% [markdown]
# #or
#
# true + true =true
# true + false = true
# false + true = true
# false + false =false

# %%
(1 < 2) or (3 > 6)
# Out:
# True

# %%
"joao" == "joao" or "Python" != "python"
# Out:
# True

# %% [markdown]
# #not

# %% [markdown]
# not true = false
# not false = true

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True
